# %%
from IPython.core.display import HTML

HTML("""
    <link rel="stylesheet" href="../fonts/cmun-bright.css">
    <style type='text/css'>
        * {
            font-family: Computer Modern Bright !important;
        }
    </style>
""")
# Out:
#     <link rel="stylesheet" href="../fonts/cmun-bright.css">
#     <style type='text/css'>
#         * {
#             font-family: Computer Modern Bright !important;
#         }
#     </style>

# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Loops (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 4.1 The for iterator

# %%
names = ["Edison", "Mathew", "Shrinjana", "Yao Ting", "Bing Heng", "Samantha", "Jun Rui", "Marcus", "Jinxia"]

# %% [markdown]
# ## 4.1.1 for with a list

# %% [markdown]
# `for` goes through every element in an iterator

# %%
for name in names:
    print(f"{name} is in the SPS committee!")
# Out:
# Edison is in the SPS committee!
# Mathew is in the SPS committee!
# Shrinjana is in the SPS committee!
# Yao Ting is in the SPS committee!
# Bing Heng is in the SPS committee!
# Samantha is in the SPS committee!
# Jun Rui is in the SPS committee!
# Marcus is in the SPS committee!
# Jinxia is in the SPS committee!

# %% [markdown]
# ## 4.1.2 for with enumerate

# %%
majors = ["Life Sciences", "Math", "Math", "Life Sciences", "Life Sciences", "Chemistry", "Physics", "Life Sciences", "Life Sciences"]

for index, name in enumerate(names):
    print(f'{index + 1}: {name} is in the SPS committee!')
# Out:
# 1: Edison is in the SPS committee!
# 2: Mathew is in the SPS committee!
# 3: Shrinjana is in the SPS committee!
# 4: Yao Ting is in the SPS committee!
# 5: Bing Heng is in the SPS committee!
# 6: Samantha is in the SPS committee!
# 7: Jun Rui is in the SPS committee!
# 8: Marcus is in the SPS committee!
# 9: Jinxia is in the SPS committee!

# %%
for index, name in enumerate(names):
    major = majors[index]
    print(f'{name} is a {major} major!')
# Out:
# Edison is a Life Sciences major!
# Mathew is a Math major!
# Shrinjana is a Math major!
# Yao Ting is a Life Sciences major!
# Bing Heng is a Life Sciences major!
# Samantha is a Chemistry major!
# Jun Rui is a Physics major!
# Marcus is a Life Sciences major!
# Jinxia is a Life Sciences major!

# %% [markdown]
# We can instead change the starting index in `enumerate()`

# %%
for index, name in enumerate(names, 1):
    print(f'{index}: {name} is in the SPS committee!')
# Out:
# 1: Edison is in the SPS committee!
# 2: Mathew is in the SPS committee!
# 3: Shrinjana is in the SPS committee!
# 4: Yao Ting is in the SPS committee!
# 5: Bing Heng is in the SPS committee!
# 6: Samantha is in the SPS committee!
# 7: Jun Rui is in the SPS committee!
# 8: Marcus is in the SPS committee!
# 9: Jinxia is in the SPS committee!

# %% [markdown]
# ## 4.1.3 for with range

# %% [markdown]
# `range()` returns an iterable of datatype `range`

# %%
print(range(5))
# Out:
# range(0, 5)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5, 10):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
for i in range(1, 10, 3):
    print(i)
# Out:
# 1
# 4
# 7

# %%
for i in range(len(names)):
    name = names[i]
    major = majors[i]        
    print(f"{name} is in the SPS committee and is a {major} major!")
# Out:
# Edison is in the SPS committee and is a Life Sciences major!
# Mathew is in the SPS committee and is a Math major!
# Shrinjana is in the SPS committee and is a Math major!
# Yao Ting is in the SPS committee and is a Life Sciences major!
# Bing Heng is in the SPS committee and is a Life Sciences major!
# Samantha is in the SPS committee and is a Chemistry major!
# Jun Rui is in the SPS committee and is a Physics major!
# Marcus is in the SPS committee and is a Life Sciences major!
# Jinxia is in the SPS committee and is a Life Sciences major!

# %% [markdown]
# # 4.2 while

# %%
number = 0

while number < 5:
    print(number)
    number += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # Footnotes
# Referenced [Loops (Need)](https://sps.nus.edu.sg/sp2273/docs/python_basics/04_loops/1_loops_need.html)
