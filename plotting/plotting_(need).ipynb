# %%
from IPython.core.display import HTML

HTML("""
    <link rel="stylesheet" href="../fonts/cmun-bright.css">
    <style type='text/css'>
        * {
            font-family: Computer Modern Bright !important;
        }
    </style>
""")
# Out:
#     <link rel="stylesheet" href="../fonts/cmun-bright.css">
#     <style type='text/css'>
#         * {
#             font-family: Computer Modern Bright !important;
#         }
#     </style>

# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# or instead, without conda, `pip3 install matplotlib`

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# # 7.1 A simple plot

# %% [markdown]
# ## 7.1.1 Let’s look at some code.

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
# plt.grid(alpha=.25)
plt.grid(alpha=.8)
# plt.legend(loc='upper left')
plt.legend(loc='lower left')

plt.show()

# %% [markdown]
# ### Things to note

# %% [markdown]
# | Long form     | Abbreviation |
# |---------------|--------------|
# | `color`       | `c`          |
# | `linestyle`   | `ls`         |
# | `linewidth`   | `lw`         |
#
# and some other additional abbreviations!
#
# | Long form         | Abbreviation |
# |-------------------|--------------|
# | `markersize`      | `ms`         |
# | `markeredgecolor` | `mec`        |
# | `markeredgewidth` | `mew`        |
# | `markerfacecolor` | `mfc`        |
# | `alpha`           | `a`          |

# %%
plt.plot(x, y_1, color='red',
         linestyle='dashed', linewidth=2)

plt.show()

# %%
plt.plot(x, y_2, c='red', ls='dashed', lw=2)

plt.show()

# %% [markdown]
# ## 7.1.2 Adding another plot
#
# We can have multiple plots on the same plot!

# %%
# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed')
plt.plot(x, y_2, label='Y2 values', color='blue')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# ## 7.1.3 Yet another plot but with error bars
#
# We can include error bars to a specific plot using `errorbar()`
#
# An Example using constant error values:

# %%
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# # 7.2 Better with NumPy
#
# `matplotlib` works natively with `numpy` `array` as well!

# %%
import numpy as np

# %%
np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')

plt.show()

# %% [markdown]
# ## 7.2.1 Adding mathematical functions
#
# Here is a prime example of why `numpy` `array` can be a lot more powerful than native primitive `list`

# %%
x = np.linspace(0, np.pi, 1000)

x2 = x**2                  # The math stuff
cos_x = np.cos(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed', )
plt.plot(x, cos_x, label='cos(x)',
         color='blue')
plt.legend()

plt.show()

# %% [markdown]
# ## We need another axis!
#
# `twinx()`

# %%
plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()

plt.plot(x, cos_x, label='cos(x)',color='blue', )
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# # 7.3 Saving to disc
#
# `matplotlib` provides a very straightforward way to save your plots to a file using the `savefig()` function, allowing for tons of flexibility in terms of file format, resolution, and save location.
#
# Again, we can use `os.path` to make it OS safe and construct OS specific filepaths

# %%
import os

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed')
plt.legend(loc='lower left')
plt.twinx()
plt.plot(x, cos_x,
         label='sin x', color='blue')
plt.legend(loc='lower right')

filename = 'simple-plot.png'
desktop_path = os.path.join(".", filename)
plt.savefig(desktop_path, dpi=150)

# %% [markdown]
# # 7.4 A real example: Global Warming

# %% [markdown]
# ## 7.4.1 Plotting data from files

# %%
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-3, 3.5])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

plt.title("Temperature anomaly\n(Relative to average from Jan 1951 - Dec 1980.)")
plt.xlabel("Date")
plt.ylabel("Temperature Anomaly")

plt.show()

# %% [markdown]
# ## 7.4.2 Styles
#
# [fivethirtyeight!](https://abcnews.go.com/538)

# %%
plt.plot(date, anomaly, alpha=.5)
plt.ylim([-3, 3.5])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

plt.title("Temperature anomaly\n(Relative to average from Jan 1951 - Dec 1980.)")
plt.xlabel("Date")
plt.ylabel("Temperature Anomaly")
plt.style.use('fivethirtyeight')

plt.show()

# %% [markdown]
# ### xkcd!

# %%
plt.plot(date, anomaly, alpha=.5)
plt.ylim([-3, 3.5])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

plt.title("Temperature anomaly\n(Relative to average from Jan 1951 - Dec 1980.)")
plt.xlabel("Date")
plt.ylabel("Temperature Anomaly")
plt.axis()
plt.xkcd()

plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# ...

# %% [markdown]
# ### Resetting styles
#
# and we can result styles as such

# %%
plt.style.use('default')

# %% [markdown]
# # LET'S HAVE SOME FUN

# %%
from math import pi, sin, sqrt

theta = lambda x : 1 * (x > 0)
sgn = lambda x : x / abs(x) if x != 0  else 1

# %%
xt = lambda t : ((-199/9 * sin(11/7 - 5 * t) - 35/9 * sin(11/7 - 4 * t) - 356/7 * sin(8/5 - 3 * t) - 60 * sin(8/5 - 2 * t) + 523/6 * sin(t + 8/5) + 7/2 * sin(6 * t + 8/5) - 784/5) * theta(151 * pi - t) * theta(t - 147 * pi) + (-3/7 * sin(11/7 - 5 * t) - 14/3 * sin(8/5 - 3 * t) + 158/3 * sin(t + 8/5) + 155/4 * sin(2 * t + 8/5) + 49/3 * sin(4 * t + 8/5) - 2059/3) * theta(147 * pi - t) * theta(t - 143 * pi) + (535/6 * sin(t + 8/5) + 4 * sin(2 * t + 14/3) + 71/8 * sin(3 * t + 8/5) + 14/5 * sin(5 * t + 8/5) + 1/7 * sin(6 * t + 23/5) + 469/9) * theta(143 * pi - t) * theta(t - 139 * pi) + (11/4 * sin(t + 8/5) + 106/3 * sin(2 * t + 8/5) + 43/14 * sin(3 * t + 14/3) + 23/3 * sin(4 * t + 8/5) + 10/9 * sin(5 * t + 14/3) + 23/6 * sin(6 * t + 8/5) - 179/3) * theta(139 * pi - t) * theta(t - 135 * pi) + (-1/10 * sin(6/5 - 5 * t) - 26/5 * sin(8/5 - 4 * t) - 64/3 * sin(8/5 - 2 * t) - 62/7 * sin(8/5 - t) + 1/23 * sin(3 * t + 1/3) - 543/4) * theta(135 * pi - t) * theta(t - 131 * pi) + (-9/4 * sin(3/2 - 121 * t) - 12/5 * sin(3/2 - 120 * t) - 7/8 * sin(5/4 - 118 * t) - 4/5 * sin(5/6 - 115 * t) - 5/3 * sin(6/7 - 113 * t) - 13/5 * sin(4/3 - 105 * t) - 8/3 * sin(5/4 - 97 * t) - 23/5 * sin(7/5 - 94 * t) - 39/5 * sin(7/5 - 90 * t) - 38/5 * sin(7/5 - 87 * t) - 28/3 * sin(11/7 - 80 * t) - 27/5 * sin(3/2 - 75 * t) - 74/5 * sin(3/2 - 74 * t) - 62/7 * sin(4/3 - 71 * t) - 37/5 * sin(7/5 - 67 * t) - 22/5 * sin(3/2 - 65 * t) - 29/4 * sin(5/4 - 63 * t) - 41/4 * sin(7/5 - 59 * t) - 25 * sin(3/2 - 58 * t) - 107/6 * sin(7/5 - 55 * t) - 186/7 * sin(3/2 - 54 * t) - 136/3 * sin(3/2 - 51 * t) - 5 * sin(4/3 - 50 * t) - 25/2 * sin(7/5 - 47 * t) - 23/2 * sin(10/7 - 46 * t) - 127/4 * sin(3/2 - 41 * t) - 55/3 * sin(10/7 - 40 * t) - 71/5 * sin(3/2 - 39 * t) - 66/5 * sin(3/2 - 36 * t) - 241/7 * sin(8/5 - 29 * t) - 20 * sin(11/7 - 25 * t) - 61/4 * sin(11/7 - 22 * t) - 9 * sin(3/2 - 11 * t) - 14/3 * sin(7/5 - 8 * t) - 17/4 * sin(7/5 - 7 * t) - 228/7 * sin(11/7 - 5 * t) - 26 * sin(11/7 - 3 * t) - 4831/16 * sin(8/5 - 2 * t) + 4471/4 * sin(t + 8/5) + 80 * sin(4 * t + 8/5) + 171/4 * sin(6 * t + 8/5) + 49/3 * sin(9 * t + 8/5) + 31/8 * sin(10 * t + 14/3) + 13/4 * sin(12 * t + 9/2) + 77/5 * sin(13 * t + 14/3) + 13/2 * sin(14 * t + 23/5) + 67/3 * sin(15 * t + 33/7) + 118/5 * sin(16 * t + 14/3) + 97/4 * sin(17 * t + 14/3) + 28/5 * sin(18 * t + 5/3) + 122/5 * sin(19 * t + 14/3) + 29/4 * sin(20 * t + 14/3) + 21/2 * sin(21 * t + 8/5) + 47/4 * sin(23 * t + 7/4) + 12 * sin(24 * t + 23/5) + 142/5 * sin(26 * t + 14/3) + 226/9 * sin(27 * t + 23/5) + 61/5 * sin(28 * t + 7/4) + 7/4 * sin(30 * t + 22/5) + 12/5 * sin(31 * t + 10/3) + 82/9 * sin(32 * t + 32/7) + 40/3 * sin(33 * t + 14/3) + 199/5 * sin(34 * t + 14/3) + 17/3 * sin(35 * t + 7/4) + 98/5 * sin(37 * t + 8/5) + 217/5 * sin(38 * t + 8/5) + 25/2 * sin(42 * t + 5/3) + 199/8 * sin(43 * t + 11/7) + 63/5 * sin(44 * t + 11/7) + 52/5 * sin(45 * t + 11/7) + 28/5 * sin(48 * t + 11/6) + 39/2 * sin(49 * t + 7/4) + 17/3 * sin(52 * t + 15/7) + 70/3 * sin(53 * t + 9/5) + 38/5 * sin(56 * t + 23/12) + 131/6 * sin(57 * t + 7/4) + 99/5 * sin(60 * t + 5/3) + 13/3 * sin(61 * t + 9/2) + 21/5 * sin(62 * t + 6/5) + 33/4 * sin(64 * t + 9/5) + 57/8 * sin(66 * t + 11/7) + 25/4 * sin(68 * t + 5/3) + 4/3 * sin(69 * t + 2/5) + 229/12 * sin(70 * t + 8/5) + 7/5 * sin(72 * t + 4/3) + 36/5 * sin(73 * t + 8/5) + 63/5 * sin(76 * t + 8/5) + 10/3 * sin(77 * t + 5/3) + 11/7 * sin(78 * t + 3/2) + 37/4 * sin(79 * t + 8/5) + 11/4 * sin(81 * t + 9/4) + 47/4 * sin(82 * t + 33/7) + 8/3 * sin(83 * t + 14/3) + 15/8 * sin(84 * t + 23/5) + 97/12 * sin(85 * t + 14/3) + 47/4 * sin(86 * t + 8/5) + 17/4 * sin(88 * t + 8/5) + 43/4 * sin(89 * t + 5/3) + 4 * sin(91 * t + 8/5) + 13/5 * sin(92 * t + 23/5) + 13/4 * sin(93 * t + 7/4) + 3/5 * sin(95 * t + 9/4) + 1/4 * sin(96 * t + 1/4) + 3/2 * sin(98 * t + 5/3) + 11/5 * sin(99 * t + 10/7) + 6/5 * sin(100 * t + 3/4) + 10/7 * sin(101 * t + 3/7) + 60/7 * sin(102 * t + 8/5) + 15/7 * sin(103 * t + 11/7) + 23/6 * sin(104 * t + 7/5) + 22/7 * sin(106 * t + 22/5) + 2 * sin(107 * t + 12/5) + 32/3 * sin(108 * t + 14/3) + 11/4 * sin(109 * t + 14/3) + 23/8 * sin(110 * t + 22/5) + 7/4 * sin(111 * t + 25/12) + 5/3 * sin(112 * t + 11/10) + 42/5 * sin(114 * t + 11/7) + 18/5 * sin(116 * t + 8/7) + 23/5 * sin(117 * t + 4/3) + 23/5 * sin(119 * t + 8/5) + 1959/5) * theta(131 * pi - t) * theta(t - 127 * pi) + (-15/2 * sin(3/4 - 104 * t) - 13/7 * sin(9/8 - 101 * t) - 2/5 * sin(3/5 - 100 * t) - 9/2 * sin(3/5 - 99 * t) - 27/4 * sin(26/25 - 96 * t) - 29/4 * sin(3/7 - 93 * t) - 14/3 * sin(3/2 - 92 * t) - 43/11 * sin(3/2 - 90 * t) - 10/3 * sin(7/6 - 84 * t) - 71/7 * sin(5/6 - 83 * t) - 41/8 * sin(7/6 - 80 * t) - 27/5 * sin(5/4 - 78 * t) - 2 * sin(1/4 - 77 * t) - 10/3 * sin(1 - 75 * t) - 62/3 * sin(13/12 - 72 * t) - 92/13 * sin(5/4 - 67 * t) - 109/7 * sin(4/3 - 63 * t) - 61/4 * sin(7/5 - 61 * t) - 39/5 * sin(5/6 - 60 * t) - 14/3 * sin(18/17 - 58 * t) - 151/8 * sin(5/4 - 57 * t) - 31/8 * sin(6/5 - 56 * t) - 14/3 * sin(1/7 - 53 * t) - 119/5 * sin(9/7 - 52 * t) - 78/5 * sin(5/4 - 49 * t) - 90/7 * sin(5/4 - 48 * t) - 206/5 * sin(5/4 - 47 * t) - 109/5 * sin(5/4 - 46 * t) - 153/5 * sin(4/3 - 42 * t) - 445/12 * sin(5/4 - 41 * t) - 289/9 * sin(4/3 - 37 * t) - 137/6 * sin(4/3 - 33 * t) - 13 * sin(5/4 - 32 * t) - 72/5 * sin(7/5 - 31 * t) - 71/5 * sin(4/3 - 28 * t) - 183/5 * sin(7/5 - 27 * t) - 158/5 * sin(7/5 - 24 * t) - 49/10 * sin(7/5 - 20 * t) - 311/8 * sin(10/7 - 19 * t) - 95/4 * sin(10/7 - 18 * t) - 85/3 * sin(3/2 - 16 * t) - 329/8 * sin(3/2 - 15 * t) - 297/5 * sin(3/2 - 11 * t) - 238/5 * sin(3/2 - 10 * t) - 187/5 * sin(3/2 - 9 * t) - 197/2 * sin(3/2 - 6 * t) - 1671/11 * sin(11/7 - 5 * t) - 894/5 * sin(11/7 - 3 * t) + 12068/9 * sin(t + 8/5) + 45/4 * sin(2 * t + 8/5) + 121/10 * sin(4 * t + 8/5) + 323/12 * sin(7 * t + 33/7) + 77/5 * sin(8 * t + 8/5) + 97/5 * sin(12 * t + 8/5) + 135/8 * sin(13 * t + 7/4) + 13/3 * sin(14 * t + 14/3) + 11/4 * sin(17 * t + 9/2) + 56/3 * sin(21 * t + 7/4) + 201/4 * sin(22 * t + 7/4) + 25/7 * sin(23 * t + 9/5) + 3/5 * sin(25 * t + 3) + 207/13 * sin(26 * t + 7/4) + 39/2 * sin(29 * t + 15/8) + 172/5 * sin(30 * t + 7/4) + 215/9 * sin(34 * t + 7/4) + 35 * sin(35 * t + 11/6) + 13/7 * sin(36 * t + 4/3) + 7/3 * sin(38 * t + 4/3) + 33/2 * sin(39 * t + 2) + 5/2 * sin(40 * t + 35/17) + 29 * sin(43 * t + 13/7) + 10 * sin(44 * t + 19/9) + 35/9 * sin(45 * t + 27/13) + 65/6 * sin(50 * t + 19/9) + 145/4 * sin(51 * t + 15/8) + 10/3 * sin(54 * t + 4) + 27/4 * sin(55 * t + 15/8) + 49/6 * sin(59 * t + 14/3) + 275/12 * sin(62 * t + 17/9) + 11/3 * sin(64 * t + 1/5) + 24/7 * sin(65 * t + 4) + 13/4 * sin(66 * t + 1/10) + 82/5 * sin(68 * t + 49/24) + 37/9 * sin(69 * t + 13/7) + 16/5 * sin(70 * t + 5/2) + 19/2 * sin(71 * t + 13/7) + 31/7 * sin(73 * t + 11/6) + 55/4 * sin(74 * t + 13/6) + 22/7 * sin(76 * t + 49/24) + 35/3 * sin(79 * t + 25/13) + 19/3 * sin(81 * t + 27/13) + 49/16 * sin(82 * t + 5/2) + 43/6 * sin(85 * t + 17/8) + 10/7 * sin(86 * t + 18/7) + 76/11 * sin(87 * t + 13/7) + 8/5 * sin(88 * t + 17/4) + 37/6 * sin(89 * t + 8/5) + 25/2 * sin(91 * t + 2) + 5/2 * sin(94 * t + 7/2) + 131/12 * sin(95 * t + 21/10) + 17/3 * sin(97 * t + 2) + 11/6 * sin(98 * t + 17/6) + 11/6 * sin(102 * t + 18/7) + 23/12 * sin(103 * t + 5/2) + 407/4) * theta(127 * pi - t) * theta(t - 123 * pi) + (-1/4 * sin(1/6 - 61 * t) - 1/6 * sin(3/4 - 60 * t) - 1/3 * sin(4/3 - 46 * t) - 1/4 * sin(5/4 - 33 * t) + 158 * sin(t + 8/5) + 240 * sin(2 * t + 14/3) + 321/7 * sin(3 * t + 14/3) + 92/3 * sin(4 * t + 14/3) + 118/5 * sin(5 * t + 3/2) + 23/4 * sin(6 * t + 14/3) + 6/5 * sin(7 * t + 7/5) + 29/3 * sin(8 * t + 14/3) + 22/3 * sin(9 * t + 14/3) + 1/4 * sin(10 * t + 17/4) + 37/6 * sin(11 * t + 10/7) + 52/5 * sin(12 * t + 3/2) + 9/2 * sin(13 * t + 10/7) + 61/5 * sin(14 * t + 23/5) + 39/4 * sin(15 * t + 23/5) + 2 * sin(16 * t + 3/2) + 26/5 * sin(17 * t + 4/3) + 31/4 * sin(18 * t + 10/7) + 66/5 * sin(19 * t + 23/5) + 25/3 * sin(20 * t + 9/2) + 7/4 * sin(21 * t + 19/4) + 53/6 * sin(22 * t + 7/5) + 41/10 * sin(23 * t + 4/3) + 13/3 * sin(24 * t + 9/2) + 25/2 * sin(25 * t + 9/2) + 7/5 * sin(26 * t + 3/2) + 12/5 * sin(27 * t + 32/7) + 18/5 * sin(28 * t + 4/3) + 22/7 * sin(29 * t + 9/2) + 10/3 * sin(30 * t + 9/2) + 7/3 * sin(31 * t + 4/3) + 49/12 * sin(32 * t + 5/4) + 22/5 * sin(34 * t + 4/3) + 35/9 * sin(35 * t + 31/7) + 3/2 * sin(36 * t + 13/3) + 5/3 * sin(37 * t + 22/5) + 31/7 * sin(38 * t + 31/7) + 76/11 * sin(39 * t + 5/4) + 4/5 * sin(40 * t + 1) + 3/2 * sin(41 * t + 5/4) + 5/2 * sin(42 * t + 6/5) + 43/11 * sin(43 * t + 13/3) + 4/3 * sin(44 * t + 7/6) + 13/3 * sin(45 * t + 30/7) + 35/12 * sin(47 * t + 5/4) + 1/3 * sin(48 * t + 3/4) + 7/4 * sin(49 * t + 5/4) + 71/10 * sin(50 * t + 13/3) + 13/4 * sin(51 * t + 5/4) + 6/7 * sin(52 * t + 31/7) + 3/2 * sin(53 * t + 6/5) + 5/3 * sin(54 * t + 22/5) + 3/2 * sin(55 * t + 17/4) + 7/4 * sin(56 * t + 7/6) + 35/17 * sin(57 * t + 17/4) + 5/4 * sin(58 * t + 22/5) + 39/8 * sin(59 * t + 7/6) + 1/3 * sin(62 * t + 17/5) + 7/8 * sin(63 * t + 13/3) + 9/4 * sin(64 * t + 21/5) + 3/4 * sin(65 * t + 26/25) + 1/3 * sin(66 * t + 17/7) + 11/5 * sin(67 * t + 22/5) + 14/5 * sin(68 * t + 8/7) + 7/8 * sin(69 * t + 4/7) + 5/4 * sin(70 * t + 69/17) + 3/2 * sin(71 * t + 13/3) + 21/11 * sin(72 * t + 6/5) + 9/4 * sin(73 * t + 13/3) + 2/3 * sin(74 * t + 5/3) + 13/4 * sin(75 * t + 17/4) + 6/7 * sin(76 * t + 5/4) + 8/5 * sin(77 * t + 22/5) + 5/3 * sin(78 * t + 6/5) + 13/5 * sin(79 * t + 13/3) + 1/2 * sin(80 * t + 13/6) + 9/8 * sin(81 * t + 23/5) - 633/5) * theta(123 * pi - t) * theta(t - 119 * pi) + (-3/5 * sin(3/2 - 6 * t) - 3/2 * sin(3/2 - 4 * t) - 196/15 * sin(8/5 - 3 * t) - 25/6 * sin(8/5 - 2 * t) - 682/5 * sin(8/5 - t) + 23/5 * sin(5 * t + 33/7) - 510) * theta(119 * pi - t) * theta(t - 115 * pi) + (-1/7 * sin(5/4 - 6 * t) - 67/17 * sin(11/7 - 5 * t) - 1/2 * sin(7/5 - 4 * t) - 35/3 * sin(8/5 - 3 * t) - 601/5 * sin(8/5 - t) + 1/9 * sin(2 * t + 8/7) + 722/5) * theta(115 * pi - t) * theta(t - 111 * pi) + (-11/5 * sin(8/5 - 5 * t) - 29/4 * sin(8/5 - 3 * t) - 181 * sin(8/5 - t) + 25/3 * sin(2 * t + 8/5) + 7/6 * sin(4 * t + 8/5) - 521) * theta(111 * pi - t) * theta(t - 107 * pi) + (563/3 * sin(t + 8/5) + 16/5 * sin(2 * t + 8/5) + 52/5 * sin(3 * t + 8/5) + 5/4 * sin(4 * t + 14/3) + 11/2 * sin(5 * t + 8/5) + 1/19 * sin(6 * t + 14/3) + 158) * theta(107 * pi - t) * theta(t - 103 * pi) + (-121/2 * sin(8/5 - t) + 113/7 * sin(2 * t + 33/7) + 5/2 * sin(3 * t + 14/3) + 14/3 * sin(4 * t + 19/4) + 14/5 * sin(5 * t + 19/4) - 1067/4) * theta(103 * pi - t) * theta(t - 99 * pi) + (-16/5 * sin(8/5 - 3 * t) - 64/7 * sin(8/5 - t) + 6 * sin(2 * t + 8/5) + 7/4 * sin(4 * t + 8/5) + 4/3 * sin(5 * t + 19/4) - 598/7) * theta(99 * pi - t) * theta(t - 95 * pi) + (-8/5 * sin(8/5 - 6 * t) - 185/4 * sin(8/5 - 2 * t) + 301/3 * sin(t + 8/5) + 31/6 * sin(3 * t + 8/5) + 17/5 * sin(4 * t + 8/5) + 19/3 * sin(5 * t + 8/5) + 707/4) * theta(95 * pi - t) * theta(t - 91 * pi) + (-17/9 * sin(3/2 - 28 * t) - 8/5 * sin(3/2 - 27 * t) - 11/4 * sin(3/2 - 26 * t) - 5/4 * sin(3/2 - 25 * t) - 2 * sin(3/2 - 24 * t) - 33/2 * sin(3/2 - 18 * t) - 16/3 * sin(3/2 - 17 * t) - 88/5 * sin(11/7 - 12 * t) - 45/2 * sin(3/2 - 11 * t) - 235/7 * sin(11/7 - 8 * t) - 122/5 * sin(11/7 - 7 * t) - 29/2 * sin(11/7 - 6 * t) - 946/21 * sin(11/7 - 3 * t) + 512/3 * sin(t + 8/5) + 109/2 * sin(2 * t + 8/5) + 199/5 * sin(4 * t + 8/5) + 173/6 * sin(5 * t + 8/5) + 23/5 * sin(9 * t + 8/5) + 1/4 * sin(10 * t + 16/5) + 17/4 * sin(13 * t + 8/5) + 8/9 * sin(14 * t + 5/3) + 21/2 * sin(15 * t + 8/5) + 71/6 * sin(16 * t + 8/5) + 3 * sin(19 * t + 5/3) + 1/8 * sin(20 * t + 10/3) + 4/5 * sin(21 * t + 3/2) + 14/3 * sin(22 * t + 5/3) + 47/12 * sin(23 * t + 8/5) + 2 * sin(29 * t + 5/3) - 722/3) * theta(91 * pi - t) * theta(t - 87 * pi) + (-1/3 * sin(11/7 - 10 * t) - 10/3 * sin(8/5 - 7 * t) - 10/3 * sin(8/5 - 4 * t) - 111/5 * sin(8/5 - 3 * t) + 391/10 * sin(t + 8/5) + 483/11 * sin(2 * t + 8/5) + 1/3 * sin(5 * t + 8/5) + 2/5 * sin(6 * t + 14/3) + 24/7 * sin(8 * t + 8/5) + 1/4 * sin(9 * t + 8/5) - 2427/5) * theta(87 * pi - t) * theta(t - 83 * pi) + (-9/5 * sin(8/5 - 10 * t) - 25/4 * sin(8/5 - 6 * t) - 2/5 * sin(3/2 - 4 * t) - 94 * sin(8/5 - 2 * t) - 32/7 * sin(11/7 - t) + 73/9 * sin(3 * t + 8/5) + 17/5 * sin(5 * t + 8/5) + 11/5 * sin(7 * t + 8/5) + 1/11 * sin(8 * t + 14/3) + 9/4 * sin(9 * t + 8/5) + 333/5) * theta(83 * pi - t) * theta(t - 79 * pi) + (-19/4 * sin(8/5 - 7 * t) - 5/2 * sin(8/5 - 6 * t) - 7/2 * sin(8/5 - 4 * t) - 135/7 * sin(8/5 - 3 * t) - 69/4 * sin(8/5 - 2 * t) - 963/7 * sin(8/5 - t) + 8 * sin(5 * t + 19/4) + 4247/9) * theta(79 * pi - t) * theta(t - 75 * pi) + (-19/3 * sin(11/7 - 6 * t) - 67/6 * sin(11/7 - 5 * t) - 32/7 * sin(3/2 - 4 * t) - 125/4 * sin(8/5 - 3 * t) - 161/5 * sin(11/7 - 2 * t) - 433/4 * sin(8/5 - t) + 280) * theta(75 * pi - t) * theta(t - 71 * pi) + (298/3 * sin(t + 8/5) + 937/24 * sin(2 * t + 8/5) + 34/5 * sin(3 * t + 19/4) + 129/8 * sin(4 * t + 8/5) + 21/10 * sin(5 * t + 14/3) + 13/2 * sin(6 * t + 8/5) + 10/11 * sin(7 * t + 14/3) + 16/5 * sin(8 * t + 8/5) + 1/4 * sin(9 * t + 11/6) + 43/14 * sin(10 * t + 8/5) - 1191/2) * theta(71 * pi - t) * theta(t - 67 * pi) + (-1/4 * sin(10/9 - 9 * t) - 63/2 * sin(8/5 - 6 * t) - 80/3 * sin(8/5 - 4 * t) - 128/5 * sin(8/5 - t) + 10 * sin(2 * t + 8/5) + 25/2 * sin(3 * t + 8/5) + 51/2 * sin(5 * t + 8/5) + 4 * sin(7 * t + 33/7) + 125/6 * sin(8 * t + 8/5) + 19/3 * sin(10 * t + 14/3) - 2787/4) * theta(67 * pi - t) * theta(t - 63 * pi) + (-7/3 * sin(3/2 - 22 * t) - 18/7 * sin(3/2 - 21 * t) - 29/10 * sin(3/2 - 20 * t) - 35/3 * sin(11/7 - 17 * t) - 80/3 * sin(11/7 - 15 * t) - 161/3 * sin(11/7 - 13 * t) - 58/5 * sin(3/2 - 12 * t) - 97/3 * sin(11/7 - 9 * t) - 157/4 * sin(11/7 - 8 * t) - 317/6 * sin(11/7 - 7 * t) - 133/4 * sin(11/7 - 6 * t) - 65/3 * sin(11/7 - 5 * t) - 113/4 * sin(11/7 - 4 * t) - 228/7 * sin(8/5 - 3 * t) - 283/4 * sin(8/5 - 2 * t) - 417/5 * sin(8/5 - t) + 5/4 * sin(10 * t + 3/2) + 317/6 * sin(11 * t + 8/5) + 118/3 * sin(14 * t + 8/5) + 11/4 * sin(16 * t + 10/7) + 17/2 * sin(18 * t + 8/5) + 4/5 * sin(19 * t + 7/4) + 4/3 * sin(23 * t + 8/5) + 1641/4) * theta(63 * pi - t) * theta(t - 59 * pi) + (-17/2 * sin(11/7 - 10 * t) - 24/5 * sin(3/2 - 8 * t) - 72/5 * sin(8/5 - 6 * t) - 3/4 * sin(7/5 - 5 * t) - 122/3 * sin(8/5 - 4 * t) - 225 * sin(8/5 - 2 * t) - 88/5 * sin(11/7 - t) + 19/4 * sin(3 * t + 3/2) + 3 * sin(7 * t + 8/5) + 1/3 * sin(9 * t + 5/3) + 1938/7) * theta(59 * pi - t) * theta(t - 55 * pi) + (2311/15 * sin(t + 8/5) + 27/5 * sin(2 * t + 14/3) + 441/22 * sin(3 * t + 8/5) + 27/7 * sin(4 * t + 14/3) + 27/5 * sin(5 * t + 8/5) + 5/3 * sin(6 * t + 14/3) + 9/4 * sin(7 * t + 8/5) + 15/14 * sin(8 * t + 33/7) + 7/4 * sin(9 * t + 8/5) + 2/3 * sin(10 * t + 33/7) + 2037/4) * theta(55 * pi - t) * theta(t - 51 * pi) + (-49/4 * sin(4/3 - 3 * t) + 263/5 * sin(t + 3/2) + 3116/5 * sin(2 * t + 11/7) + 195/7 * sin(4 * t + 9/2) + 6/5 * sin(5 * t + 4/5) + 377/9 * sin(6 * t + 3/2) + 49/3 * sin(7 * t + 14/3) + 38/5 * sin(8 * t + 11/7) + 3/4 * sin(9 * t + 3/5) + 26/3 * sin(10 * t + 5/3) - 127/6) * theta(51 * pi - t) * theta(t - 47 * pi) + (-11/4 * sin(3/2 - 9 * t) - 21/5 * sin(11/7 - 7 * t) - 239/4 * sin(8/5 - 3 * t) + 1673/3 * sin(t + 8/5) + 391/2 * sin(2 * t + 8/5) + 70 * sin(4 * t + 8/5) + 127/7 * sin(5 * t + 14/3) + 91/5 * sin(6 * t + 8/5) + 97/12 * sin(8 * t + 8/5) + 11/2 * sin(10 * t + 8/5) - 581/3) * theta(47 * pi - t) * theta(t - 43 * pi) + (-1/6 * sin(4/5 - 28 * t) - 17/3 * sin(11/7 - 27 * t) - 6/7 * sin(3/2 - 26 * t) - 3/4 * sin(11/7 - 25 * t) - 23/8 * sin(11/7 - 23 * t) - 121/8 * sin(11/7 - 15 * t) - 75/4 * sin(11/7 - 14 * t) - 33/5 * sin(11/7 - 13 * t) - 17/5 * sin(8/5 - 6 * t) + 157 * sin(t + 8/5) + 4/5 * sin(2 * t + 14/3) + 92/5 * sin(3 * t + 8/5) + 51/4 * sin(4 * t + 8/5) + 18/5 * sin(5 * t + 8/5) + 1/3 * sin(7 * t + 10/7) + 13/3 * sin(8 * t + 11/7) + 9/4 * sin(9 * t + 33/7) + 5/3 * sin(10 * t + 14/3) + 58/5 * sin(11 * t + 8/5) + 87/4 * sin(12 * t + 8/5) + 73/5 * sin(16 * t + 8/5) + 21/4 * sin(17 * t + 8/5) + 4/5 * sin(18 * t + 9/2) + 177/11 * sin(19 * t + 8/5) + 1/2 * sin(20 * t + 8/5) + 19/6 * sin(21 * t + 8/5) + 66/7 * sin(22 * t + 8/5) + 51/10 * sin(24 * t + 8/5) + 978/5) * theta(43 * pi - t) * theta(t - 39 * pi) + (-19/7 * sin(8/5 - 23 * t) - 27/4 * sin(8/5 - 16 * t) - 44/5 * sin(11/7 - 14 * t) - 7/3 * sin(8/5 - 11 * t) - 3/2 * sin(3/2 - 7 * t) - 546/5 * sin(8/5 - t) + 21/2 * sin(2 * t + 8/5) + 5/4 * sin(3 * t + 3/2) + 157/7 * sin(4 * t + 8/5) + 51/5 * sin(5 * t + 8/5) + 71/9 * sin(6 * t + 8/5) + 3 * sin(8 * t + 8/5) + 29/5 * sin(9 * t + 8/5) + 58/7 * sin(10 * t + 8/5) + 1/8 * sin(12 * t + 17/7) + 11/4 * sin(13 * t + 14/3) + 104/5 * sin(15 * t + 8/5) + 175/11 * sin(17 * t + 19/4) + 50/3 * sin(18 * t + 8/5) + 16/3 * sin(19 * t + 3/2) + 11/4 * sin(20 * t + 8/5) + 48/5 * sin(21 * t + 14/3) + 1/4 * sin(22 * t + 10/3) + 23/7 * sin(24 * t + 8/5) + 1/4 * sin(25 * t + 4/3) + 10/3 * sin(26 * t + 3/2) + 9/4 * sin(27 * t + 11/7) - 2285/4) * theta(39 * pi - t) * theta(t - 35 * pi) + (-29/5 * sin(11/7 - 13 * t) - 58/5 * sin(3/2 - 11 * t) - 53/6 * sin(3/2 - 8 * t) - 45/4 * sin(11/7 - 7 * t) - 109/5 * sin(11/7 - 6 * t) - 183/4 * sin(11/7 - 5 * t) - 152/5 * sin(11/7 - 4 * t) - 44/3 * sin(11/7 - 2 * t) + 286/5 * sin(t + 8/5) + 161/2 * sin(3 * t + 8/5) + 19/4 * sin(9 * t + 8/5) + 65/3 * sin(10 * t + 8/5) + 3/2 * sin(12 * t + 3/2) + 27/7 * sin(14 * t + 8/5) + 4632/5) * theta(35 * pi - t) * theta(t - 31 * pi) + (664/3 * sin(t + 3/5) + 83/3 * sin(2 * t + 13/3) + 78/5 * sin(3 * t + 12/5) + 48/7 * sin(4 * t + 11/4) + 32/5 * sin(5 * t + 1/8) + 32/7 * sin(6 * t + 14/3) + 2/5 * sin(7 * t + 3) + 10/11 * sin(8 * t + 7/4) + 2 * sin(9 * t + 3/4) + 11/5 * sin(10 * t + 25/6) - 1193/6) * theta(31 * pi - t) * theta(t - 27 * pi) + (-10/3 * sin(1/4 - 3 * t) - 15/4 * sin(2/5 - t) + 15/4 * sin(2 * t + 35/9) + 2/3 * sin(4 * t + 3) + 26/5 * sin(5 * t + 16/7) + 47/3 * sin(6 * t + 7/4) + 25/24 * sin(7 * t + 4) + 2 * sin(8 * t + 17/4) + 8/3 * sin(9 * t + 7/8) + 2 * sin(10 * t + 17/5) - 943/2) * theta(27 * pi - t) * theta(t - 23 * pi) + (-17/6 * sin(4/7 - 10 * t) - 19/2 * sin(1 - 6 * t) - 23/4 * sin(2/3 - 4 * t) - 40/7 * sin(9/8 - t) + 35/9 * sin(2 * t + 22/5) + 29/6 * sin(3 * t + 2/5) + 38/7 * sin(5 * t + 17/5) + 71/6 * sin(7 * t + 23/5) + 11/4 * sin(8 * t + 5/4) + 7/3 * sin(9 * t + 19/9) + 1326/7) * theta(23 * pi - t) * theta(t - 19 * pi) + (259/4 * sin(t + 5/4) + 25/7 * sin(2 * t + 10/9) - 476) * theta(19 * pi - t) * theta(t - 15 * pi) + (-41/14 * sin(1/2 - 3 * t) + 131/2 * sin(t + 1) + 2/5 * sin(2 * t + 23/6) + 1/2 * sin(4 * t + 17/4) + 548/3) * theta(15 * pi - t) * theta(t - 11 * pi) + (-8/7 * sin(2/3 - 10 * t) - 6/7 * sin(1/5 - 9 * t) - 39/19 * sin(6/7 - 8 * t) - 13/7 * sin(3/5 - 7 * t) - 15/4 * sin(7/6 - 6 * t) - 11/4 * sin(2/3 - 5 * t) - 5 * sin(4/3 - 4 * t) + 479/4 * sin(t + 3/2) + 47/6 * sin(2 * t + 23/5) + 19/4 * sin(3 * t + 5/4) - 474) * theta(11 * pi - t) * theta(t - 7 * pi) + (-15/4 * sin(7/6 - 3 * t) - 676/5 * sin(7/5 - t) + 11 * sin(2 * t + 9/5) + 7 * sin(4 * t + 9/4) + 15/4 * sin(5 * t + 23/7) + 34/7 * sin(6 * t + 3) + 4 * sin(7 * t + 19/5) + 3 * sin(8 * t + 11/3) + 35/12 * sin(9 * t + 13/3) + 7/5 * sin(10 * t + 17/4) + 937/7) * theta(7 * pi - t) * theta(t - 3 * pi) + (-52/7 * sin(1/13 - 9 * t) - 15/2 * sin(4/7 - 8 * t) - 73/5 * sin(9/7 - 7 * t) - 576/25 * sin(7/6 - 2 * t) + 4252/5 * sin(t + 13/6) + 413/5 * sin(3 * t + 1/3) + 93/5 * sin(4 * t + 9/4) + 58/5 * sin(5 * t + 61/20) + 49/2 * sin(6 * t + 23/6) + 33/8 * sin(10 * t + 8/9) + 34/3) * theta(3 * pi - t) * theta(t + pi)) * theta(sqrt(sgn(sin(t/2))))

# %%
yt = lambda t : ((-683/4 * sin(8/5 - 3 * t) - 902/17 * sin(11/7 - 2 * t) + 13/2 * sin(t + 11/7) + 280/9 * sin(4 * t + 8/5) + 10/3 * sin(5 * t + 14/3) + 41/7 * sin(6 * t + 11/7) - 1767/2) * theta(151 * pi - t) * theta(t - 147 * pi) + (-69/2 * sin(8/5 - 3 * t) - 1677/5 * sin(8/5 - t) + 7/3 * sin(2 * t + 8/5) + 2/5 * sin(4 * t + 11/7) + 47/4 * sin(5 * t + 33/7) - 7019/13) * theta(147 * pi - t) * theta(t - 143 * pi) + (303/5 * sin(t + 8/5) + 47/8 * sin(2 * t + 8/5) + 63/8 * sin(3 * t + 8/5) + 2/5 * sin(4 * t + 14/3) + 11/3 * sin(5 * t + 8/5) - 24376/25) * theta(143 * pi - t) * theta(t - 139 * pi) + (-7/6 * sin(3/2 - 6 * t) - 12/5 * sin(11/7 - 4 * t) - 34/5 * sin(8/5 - 3 * t) - 5/2 * sin(11/7 - 2 * t) - 487/4 * sin(8/5 - t) + 2 * sin(5 * t + 33/7) + 2177/16) * theta(139 * pi - t) * theta(t - 135 * pi) + (-14/5 * sin(8/5 - 5 * t) - 39/5 * sin(8/5 - 3 * t) - 389/4 * sin(8/5 - t) + 4/3 * sin(2 * t + 11/7) + 1/7 * sin(4 * t + 5/4) - 331/2) * theta(135 * pi - t) * theta(t - 131 * pi) + (-7/8 * sin(3/4 - 119 * t) - 33/4 * sin(7/5 - 118 * t) - 34/7 * sin(4/3 - 115 * t) - 19/4 * sin(10/7 - 112 * t) - 11/4 * sin(10/11 - 109 * t) - 43/5 * sin(7/6 - 106 * t) - 31/4 * sin(7/5 - 103 * t) - 7/3 * sin(3/2 - 101 * t) - 25/4 * sin(8/5 - 97 * t) - 46/7 * sin(7/5 - 92 * t) - 2 * sin(5/4 - 89 * t) - 19/10 * sin(1 - 88 * t) - 27/5 * sin(3/2 - 83 * t) - 94/7 * sin(3/2 - 81 * t) - 37/5 * sin(7/5 - 78 * t) - 16/3 * sin(3/2 - 76 * t) - 13/3 * sin(3/2 - 75 * t) - 12/5 * sin(4/5 - 71 * t) - 13/6 * sin(2/3 - 69 * t) - 73/4 * sin(7/5 - 67 * t) - 181/9 * sin(7/5 - 65 * t) - 19/18 * sin(4/3 - 63 * t) - 32/3 * sin(7/5 - 61 * t) - 75/4 * sin(10/7 - 57 * t) - 33/8 * sin(4/3 - 56 * t) - 6 * sin(4/3 - 54 * t) - 35/4 * sin(10/7 - 49 * t) - 101/4 * sin(3/2 - 48 * t) - 142/3 * sin(8/5 - 38 * t) - 15/4 * sin(4/3 - 18 * t) - 78/5 * sin(3/2 - 17 * t) - 59/4 * sin(8/5 - 16 * t) - 1162/3 * sin(8/5 - 2 * t) - 1555/3 * sin(8/5 - t) + 952/3 * sin(3 * t + 8/5) + 92/5 * sin(4 * t + 11/7) + 474/5 * sin(5 * t + 11/7) + 31/3 * sin(6 * t + 7/5) + 271/4 * sin(7 * t + 8/5) + 185/6 * sin(8 * t + 3/2) + 229/5 * sin(9 * t + 11/7) + 127/4 * sin(10 * t + 11/7) + 121/4 * sin(11 * t + 8/5) + 45/4 * sin(12 * t + 8/5) + 26/3 * sin(13 * t + 33/7) + 31/4 * sin(14 * t + 14/3) + 155/11 * sin(15 * t + 14/3) + 149/6 * sin(19 * t + 11/7) + 164/11 * sin(20 * t + 3/2) + 305/6 * sin(21 * t + 11/7) + 208/9 * sin(22 * t + 3/2) + 389/13 * sin(23 * t + 3/2) + 243/4 * sin(24 * t + 3/2) + 133/5 * sin(25 * t + 10/7) + 34 * sin(26 * t + 10/7) + 104/5 * sin(27 * t + 7/5) + 58/3 * sin(28 * t + 7/5) + 32/3 * sin(29 * t + 7/5) + 40/3 * sin(30 * t + 7/5) + 98/5 * sin(31 * t + 10/7) + 92/3 * sin(32 * t + 3/2) + 222/5 * sin(33 * t + 3/2) + 231/8 * sin(34 * t + 3/2) + 253/21 * sin(35 * t + 8/5) + 150/7 * sin(36 * t + 14/3) + 351/8 * sin(37 * t + 14/3) + 77/4 * sin(39 * t + 14/3) + 157/5 * sin(40 * t + 5/3) + 172/5 * sin(41 * t + 5/3) + 17/9 * sin(42 * t + 12/5) + 32 * sin(43 * t + 19/4) + 350/13 * sin(44 * t + 14/3) + 155/7 * sin(45 * t + 23/5) + 80/7 * sin(46 * t + 13/7) + 8/3 * sin(47 * t + 25/6) + 77/4 * sin(50 * t + 5/3) + 172/7 * sin(51 * t + 5/3) + 29/5 * sin(52 * t + 6/5) + 14/5 * sin(53 * t + 1/2) + 375/17 * sin(55 * t + 5/3) + 19/3 * sin(58 * t + 8/5) + 32/11 * sin(59 * t + 31/7) + 66/7 * sin(60 * t + 5/3) + 11/4 * sin(62 * t + 8/5) + 132/5 * sin(64 * t + 8/5) + 101/4 * sin(66 * t + 8/5) + 55/4 * sin(68 * t + 8/5) + 64/5 * sin(70 * t + 11/7) + 12 * sin(72 * t + 3/2) + 8/3 * sin(73 * t + 4/3) + 16/3 * sin(74 * t + 5/3) + 30/7 * sin(77 * t + 7/4) + 32/3 * sin(79 * t + 5/3) + 8/5 * sin(80 * t + 4/3) + 7 * sin(82 * t + 8/5) + 17/6 * sin(84 * t + 5/4) + 61/4 * sin(85 * t + 5/3) + 17/5 * sin(86 * t + 4/3) + 18/5 * sin(87 * t + 5/4) + 51/10 * sin(90 * t + 7/4) + 6/5 * sin(91 * t + 30/7) + 5/4 * sin(93 * t + 9/4) + 47/8 * sin(94 * t + 14/3) + 5/2 * sin(95 * t + 15/7) + 17/6 * sin(96 * t + 13/6) + 7/4 * sin(98 * t + 23/5) + 3 * sin(99 * t + 49/24) + 4/5 * sin(100 * t + 22/5) + 11/4 * sin(102 * t + 10/7) + 23/8 * sin(104 * t + 8/5) + 55/6 * sin(105 * t + 11/7) + 12 * sin(107 * t + 3/2) + 58/5 * sin(108 * t + 8/5) + 9/4 * sin(110 * t + 4/5) + 4/3 * sin(111 * t + 7/4) + 5/4 * sin(113 * t + 9/4) + 19/5 * sin(114 * t + 8/5) + 12/5 * sin(116 * t + 19/9) + 10/3 * sin(117 * t + 5/3) + 13/2 * sin(120 * t + 8/5) + sin(121 * t + 1/11) + 3707/7) * theta(131 * pi - t) * theta(t - 127 * pi) + (-15/4 * sin(5/6 - 103 * t) - 11/2 * sin(11/12 - 100 * t) - 8/3 * sin(15/14 - 98 * t) - 31/8 * sin(5/6 - 97 * t) - 48/5 * sin(26/25 - 95 * t) - 7/2 * sin(4/7 - 94 * t) - 5 * sin(3/4 - 89 * t) - 18/5 * sin(1 - 83 * t) - 13/5 * sin(25/24 - 80 * t) - 25/4 * sin(5/6 - 79 * t) - 6 * sin(6/7 - 76 * t) - 55/6 * sin(13/12 - 70 * t) - 31/7 * sin(1 - 69 * t) - 3 * sin(5/4 - 68 * t) - 44/5 * sin(7/6 - 67 * t) - 18 * sin(7/5 - 63 * t) - 151/6 * sin(10/7 - 61 * t) - 57/7 * sin(1/22 - 60 * t) - 91/4 * sin(7/5 - 59 * t) - 34/5 * sin(5/4 - 57 * t) - 23 * sin(7/6 - 56 * t) - 49/3 * sin(5/4 - 52 * t) - 31/5 * sin(8/5 - 49 * t) - 58/5 * sin(4/3 - 45 * t) - 41/3 * sin(6/5 - 44 * t) - 28/5 * sin(5/4 - 43 * t) - 46/5 * sin(5/4 - 42 * t) - 27/2 * sin(5/4 - 38 * t) - 183/4 * sin(7/5 - 37 * t) - 81/7 * sin(4/3 - 36 * t) - 245/6 * sin(7/5 - 35 * t) - 143/7 * sin(5/4 - 34 * t) - 25/7 * sin(3/2 - 24 * t) - 49/6 * sin(10/7 - 23 * t) - 107/4 * sin(10/7 - 22 * t) - 64/3 * sin(7/5 - 21 * t) - 17/6 * sin(6/5 - 14 * t) - 43/4 * sin(3/2 - 12 * t) - 2809/3 * sin(11/7 - 2 * t) - 336/5 * sin(11/7 - t) + 434/5 * sin(3 * t + 8/5) + 369/16 * sin(4 * t + 14/3) + 197/3 * sin(5 * t + 8/5) + 295/3 * sin(6 * t + 8/5) + 23/5 * sin(7 * t + 12/7) + 36/7 * sin(8 * t + 7/5) + 4/3 * sin(9 * t + 13/3) + 31/2 * sin(10 * t + 5/3) + 7/3 * sin(11 * t + 5/3) + 208/11 * sin(13 * t + 5/3) + 139/5 * sin(15 * t + 5/3) + 208/3 * sin(16 * t + 5/3) + 171/4 * sin(17 * t + 5/3) + 589/12 * sin(18 * t + 5/3) + 131/4 * sin(19 * t + 5/3) + 38/7 * sin(20 * t + 5/3) + 99/4 * sin(25 * t + 7/4) + 137/3 * sin(26 * t + 5/3) + 101/4 * sin(27 * t + 7/4) + 109/2 * sin(28 * t + 5/3) + 35 * sin(29 * t + 7/4) + 55 * sin(30 * t + 12/7) + 91/4 * sin(31 * t + 7/4) + 83/3 * sin(32 * t + 7/4) + 50/7 * sin(33 * t + 2) + 131/10 * sin(39 * t + 19/4) + 9 * sin(40 * t + 9/5) + 14/5 * sin(41 * t + 21/11) + 31/2 * sin(46 * t + 7/4) + 29/5 * sin(47 * t + 5/2) + 127/4 * sin(48 * t + 9/5) + 21/5 * sin(50 * t + 7/5) + 3/7 * sin(51 * t + 5/4) + 47/5 * sin(53 * t + 10/7) + 77/5 * sin(54 * t + 13/6) + 103/3 * sin(55 * t + 15/8) + 148/5 * sin(58 * t + 21/11) + 149/6 * sin(62 * t + 9/5) + 9 * sin(64 * t + 11/7) + 35/6 * sin(65 * t + 11/4) + 22/5 * sin(66 * t + 3/2) + 67/6 * sin(71 * t + 21/10) + 79/8 * sin(72 * t + 13/6) + 17/6 * sin(73 * t + 7/6) + 19/4 * sin(74 * t + 9/4) + 32/3 * sin(75 * t + 15/8) + 23/3 * sin(77 * t + 43/21) + 63/8 * sin(78 * t + 9/4) + 37/5 * sin(81 * t + 7/3) + sin(82 * t + 8/7) + 33/5 * sin(84 * t + 2) + 13/4 * sin(85 * t + 12/5) + 31/6 * sin(86 * t + 7/4) + 23/5 * sin(87 * t + 7/3) + 11/4 * sin(88 * t + 7/4) + 24/5 * sin(90 * t + 29/14) + 31/4 * sin(91 * t + 9/4) + 8/3 * sin(92 * t + 17/8) + 19/5 * sin(93 * t + 12/5) + 48/7 * sin(96 * t + 9/4) + 74/7 * sin(99 * t + 13/6) + 5 * sin(101 * t + 2) + 45/7 * sin(102 * t + 9/4) + 11/4 * sin(104 * t + 7/4) + 577) * theta(127 * pi - t) * theta(t - 123 * pi) + (-1/4 * sin(7/5 - 79 * t) - 1/5 * sin(1/12 - 67 * t) - 1/3 * sin(1 - 58 * t) - 17/5 * sin(3/2 - 19 * t) - 28/5 * sin(8/5 - 15 * t) - 32/11 * sin(11/7 - 7 * t) - 11/3 * sin(3/2 - 3 * t) + 96/5 * sin(t + 33/7) + 9 * sin(2 * t + 8/5) + 17/2 * sin(4 * t + 11/7) + 316/21 * sin(5 * t + 14/3) + 13/5 * sin(6 * t + 23/5) + 85/4 * sin(8 * t + 3/2) + 93/7 * sin(9 * t + 3/2) + 19/2 * sin(10 * t + 3/2) + 5/2 * sin(11 * t + 14/3) + 47/4 * sin(12 * t + 3/2) + 91/15 * sin(13 * t + 7/5) + 41/5 * sin(14 * t + 11/7) + 10/11 * sin(16 * t + 5/2) + 38/5 * sin(17 * t + 7/5) + 153/11 * sin(18 * t + 9/2) + 7/4 * sin(20 * t + 7/4) + 11/2 * sin(21 * t + 14/3) + 9/4 * sin(22 * t + 17/4) + 165/4 * sin(23 * t + 9/2) + 101/5 * sin(24 * t + 7/5) + 36/5 * sin(25 * t + 9/2) + 94/5 * sin(26 * t + 7/5) + 85/3 * sin(27 * t + 9/2) + 91/6 * sin(28 * t + 7/5) + 61 * sin(29 * t + 4/3) + 19/2 * sin(30 * t + 4/3) + 12 * sin(31 * t + 5/4) + 109/6 * sin(32 * t + 7/5) + 51/4 * sin(33 * t + 9/2) + 37/3 * sin(34 * t + 22/5) + 31/4 * sin(35 * t + 4/3) + 3/2 * sin(36 * t + 22/5) + 21/2 * sin(37 * t + 5/4) + 8 * sin(38 * t + 5/4) + 17/5 * sin(39 * t + 6/5) + 23/8 * sin(40 * t + 17/4) + 21/4 * sin(41 * t + 22/5) + 12/7 * sin(42 * t + 4/3) + 105/13 * sin(43 * t + 5/4) + 1/5 * sin(44 * t + 43/14) + 11/4 * sin(45 * t + 31/7) + 14/3 * sin(46 * t + 17/4) + 5/3 * sin(47 * t + 13/3) + 11/4 * sin(48 * t + 5/4) + 9/5 * sin(49 * t + 13/3) + 10/3 * sin(50 * t + 13/3) + 4 * sin(51 * t + 13/3) + 3/4 * sin(52 * t + 4/5) + 5/3 * sin(53 * t + 1) + 8/5 * sin(54 * t + 13/12) + 13/3 * sin(55 * t + 13/3) + 2 * sin(56 * t + 13/3) + 2/5 * sin(57 * t + 9/2) + 4/3 * sin(59 * t + 22/5) + 8/3 * sin(60 * t + 21/5) + 25/7 * sin(61 * t + 17/4) + 3/5 * sin(62 * t + 4) + 6/7 * sin(63 * t + 13/12) + 5/3 * sin(64 * t + 21/5) + 5/4 * sin(65 * t + 13/3) + 27/13 * sin(66 * t + 41/10) + 2/3 * sin(68 * t + 7/6) + 29/10 * sin(69 * t + 1) + 12/5 * sin(70 * t + 1) + 31/15 * sin(71 * t + 37/9) + 1/11 * sin(72 * t + 17/4) + 17/9 * sin(73 * t + 17/4) + 19/4 * sin(74 * t + 1) + 1/2 * sin(75 * t + 3/4) + 8/9 * sin(76 * t + 73/18) + 2/5 * sin(77 * t + 41/10) + 1/2 * sin(78 * t + 27/7) + 13/7 * sin(80 * t + 4) + 9/4 * sin(81 * t + 29/7) - 2103/4) * theta(123 * pi - t) * theta(t - 119 * pi) + (-27/5 * sin(8/5 - 3 * t) - 132/5 * sin(8/5 - t) + 83/5 * sin(2 * t + 8/5) + 21/5 * sin(4 * t + 8/5) + 8/5 * sin(5 * t + 14/3) + 7/3 * sin(6 * t + 8/5) + 121/2) * theta(119 * pi - t) * theta(t - 115 * pi) + (81/8 * sin(t + 8/5) + 69/4 * sin(2 * t + 8/5) + 5/2 * sin(3 * t + 14/3) + 5 * sin(4 * t + 8/5) + 3/5 * sin(5 * t + 14/3) + 13/6 * sin(6 * t + 8/5) + 545/6) * theta(115 * pi - t) * theta(t - 111 * pi) + (-89/8 * sin(8/5 - 4 * t) - 17/6 * sin(11/7 - 3 * t) - 323/5 * sin(8/5 - 2 * t) - 98/5 * sin(8/5 - t) + 2/3 * sin(5 * t + 3/2) + 838/3) * theta(111 * pi - t) * theta(t - 107 * pi) + (-23/4 * sin(8/5 - 6 * t) - 15/16 * sin(3/2 - 5 * t) - 19/2 * sin(8/5 - 4 * t) - sin(3/2 - 3 * t) - 342/5 * sin(8/5 - 2 * t) + 38/3 * sin(t + 8/5) + 772/3) * theta(107 * pi - t) * theta(t - 103 * pi) + (-751/5 * sin(8/5 - t) + 16/3 * sin(2 * t + 8/5) + 152/9 * sin(3 * t + 33/7) + 3/2 * sin(4 * t + 8/5) + 16/3 * sin(5 * t + 19/4) + 1983/4) * theta(103 * pi - t) * theta(t - 99 * pi) + (107 * sin(t + 8/5) + 11/12 * sin(2 * t + 8/5) + 34/3 * sin(3 * t + 8/5) + 1/2 * sin(4 * t + 8/5) + 4 * sin(5 * t + 8/5) + 3169/6) * theta(99 * pi - t) * theta(t - 95 * pi) + (-sin(11/7 - 6 * t) - 62/5 * sin(8/5 - 5 * t) - 1419/5 * sin(8/5 - t) + 127/9 * sin(2 * t + 14/3) + 101/3 * sin(3 * t + 19/4) + 7/5 * sin(4 * t + 8/5) - 2053/4) * theta(95 * pi - t) * theta(t - 91 * pi) + (-4/7 * sin(7/5 - 26 * t) - 14/5 * sin(3/2 - 19 * t) - 22/7 * sin(3/2 - 16 * t) - 27/13 * sin(3/2 - 15 * t) - 14/3 * sin(3/2 - 12 * t) - 8/5 * sin(11/7 - 11 * t) - 125/2 * sin(8/5 - 3 * t) - 1124/7 * sin(8/5 - t) + 952/5 * sin(2 * t + 8/5) + 780/11 * sin(4 * t + 8/5) + 63/4 * sin(5 * t + 8/5) + 41/2 * sin(6 * t + 8/5) + 19/3 * sin(7 * t + 8/5) + 104/5 * sin(8 * t + 8/5) + 4/3 * sin(9 * t + 8/5) + 53/4 * sin(10 * t + 8/5) + 2/5 * sin(13 * t + 14/3) + 82/9 * sin(14 * t + 8/5) + 2/7 * sin(17 * t + 9/2) + 47/23 * sin(18 * t + 8/5) + 13/4 * sin(20 * t + 8/5) + 65/16 * sin(21 * t + 5/3) + 47/23 * sin(22 * t + 8/5) + 12/11 * sin(23 * t + 8/5) + 13/5 * sin(24 * t + 5/3) + sin(25 * t + 5/3) + 1/9 * sin(27 * t + 14/3) + 5/3 * sin(28 * t + 5/3) - 3104/15) * theta(91 * pi - t) * theta(t - 87 * pi) + (-14/3 * sin(8/5 - 5 * t) - 91/10 * sin(8/5 - 4 * t) - 4 * sin(8/5 - 3 * t) - 217/5 * sin(8/5 - 2 * t) + 62/9 * sin(t + 8/5) + 89/22 * sin(6 * t + 19/4) + 8/7 * sin(7 * t + 8/5) + 8/9 * sin(8 * t + 14/3) + 6/7 * sin(9 * t + 14/3) + 4/5 * sin(10 * t + 14/3) - 1925/3) * theta(87 * pi - t) * theta(t - 83 * pi) + (-21/5 * sin(11/7 - 10 * t) - 7/5 * sin(11/7 - 8 * t) - 28/5 * sin(11/7 - 7 * t) - 72/5 * sin(8/5 - 6 * t) - 5/6 * sin(3/2 - 4 * t) - 50/3 * sin(8/5 - 3 * t) - 2501/20 * sin(8/5 - 2 * t) + 217/6 * sin(t + 8/5) + 22/5 * sin(5 * t + 8/5) + 2 * sin(9 * t + 8/5) - 2417/3) * theta(83 * pi - t) * theta(t - 79 * pi) + (-44/9 * sin(8/5 - 7 * t) - 212/7 * sin(8/5 - 3 * t) - 896/3 * sin(8/5 - t) + 43/5 * sin(2 * t + 8/5) + 5/2 * sin(4 * t + 8/5) + 61/6 * sin(5 * t + 33/7) + 7/4 * sin(6 * t + 11/7) - 2602/3) * theta(79 * pi - t) * theta(t - 75 * pi) + (-39/4 * sin(8/5 - 5 * t) - 157/5 * sin(8/5 - 3 * t) - 733/2 * sin(8/5 - t) + 29/2 * sin(2 * t + 11/7) + 32/5 * sin(4 * t + 11/7) + 49/12 * sin(6 * t + 8/5) - 1761/2) * theta(75 * pi - t) * theta(t - 71 * pi) + (-4 * sin(8/5 - 9 * t) - 2/5 * sin(6/5 - 8 * t) - 48/7 * sin(8/5 - 7 * t) - 2/3 * sin(5/4 - 6 * t) - 67/5 * sin(8/5 - 5 * t) - 3/5 * sin(4/3 - 4 * t) - 167/4 * sin(8/5 - 3 * t) - 1142/3 * sin(8/5 - t) + 69/17 * sin(2 * t + 11/7) + 1/3 * sin(10 * t + 7/5) - 2108/3) * theta(71 * pi - t) * theta(t - 67 * pi) + (-181/5 * sin(8/5 - 6 * t) - 74/3 * sin(11/7 - 4 * t) + 275/3 * sin(t + 8/5) + 41/3 * sin(2 * t + 8/5) + 191/6 * sin(3 * t + 8/5) + 118/3 * sin(5 * t + 8/5) + 3/4 * sin(7 * t + 14/3) + 172/7 * sin(8 * t + 8/5) + 53/5 * sin(9 * t + 8/5) + 81/5 * sin(10 * t + 33/7) - 93/5) * theta(67 * pi - t) * theta(t - 63 * pi) + (-17/7 * sin(3/2 - 21 * t) - 10/3 * sin(3/2 - 12 * t) - 116/3 * sin(11/7 - 11 * t) - 223/7 * sin(11/7 - 10 * t) - 533/4 * sin(8/5 - t) + 151/3 * sin(2 * t + 8/5) + 115/4 * sin(3 * t + 8/5) + 163/5 * sin(4 * t + 8/5) + 82/5 * sin(5 * t + 8/5) + 223/7 * sin(6 * t + 8/5) + 186/5 * sin(7 * t + 8/5) + 103/3 * sin(8 * t + 8/5) + 19/3 * sin(9 * t + 8/5) + 2/5 * sin(13 * t + 22/5) + 25/2 * sin(14 * t + 8/5) + 1/5 * sin(15 * t + 4) + 13/4 * sin(16 * t + 8/5) + 23/4 * sin(17 * t + 5/3) + 33/5 * sin(18 * t + 8/5) + 29/4 * sin(19 * t + 5/3) + 1/5 * sin(20 * t + 19/10) + 20/7 * sin(22 * t + 8/5) + 5/6 * sin(23 * t + 5/3) + 5/4) * theta(63 * pi - t) * theta(t - 59 * pi) + (-16/5 * sin(3/2 - 9 * t) - 57/5 * sin(8/5 - 8 * t) - 37/5 * sin(11/7 - 5 * t) - 129/2 * sin(8/5 - 4 * t) - 4 * sin(11/7 - 3 * t) + 153/5 * sin(t + 14/3) + 409/3 * sin(2 * t + 8/5) + 80/7 * sin(6 * t + 8/5) + 1/2 * sin(7 * t + 14/3) + 4/7 * sin(10 * t + 3/2) + 2662/5) * theta(59 * pi - t) * theta(t - 55 * pi) + (-3/4 * sin(3/2 - 10 * t) - 4/3 * sin(3/2 - 9 * t) - 5/4 * sin(3/2 - 8 * t) - 11/4 * sin(11/7 - 7 * t) - 12/5 * sin(11/7 - 6 * t) - 4 * sin(8/5 - 5 * t) - 19/3 * sin(11/7 - 4 * t) - 37/6 * sin(11/7 - 3 * t) - 49/5 * sin(11/7 - 2 * t) - 337/3 * sin(8/5 - t) + 13569/16) * theta(55 * pi - t) * theta(t - 51 * pi) + (-2 * sin(6/7 - 10 * t) - 11/4 * sin(1/3 - 6 * t) - 545/17 * sin(11/7 - 2 * t) + 50 * sin(t + 8/5) + 67/2 * sin(3 * t + 14/3) + 687/5 * sin(4 * t + 14/3) + 52/3 * sin(5 * t + 8/5) + 5/4 * sin(7 * t + 7/2) + 203/4 * sin(8 * t + 14/3) + 226/25 * sin(9 * t + 3/2) + 3932/5) * theta(51 * pi - t) * theta(t - 47 * pi) + (-83/6 * sin(8/5 - 10 * t) - 112/5 * sin(8/5 - 8 * t) - 44/5 * sin(11/7 - 6 * t) - 203/4 * sin(8/5 - 5 * t) - 461/7 * sin(8/5 - 3 * t) - 199/2 * sin(8/5 - 2 * t) + 32 * sin(t + 8/5) + 252/11 * sin(4 * t + 8/5) + 29/5 * sin(7 * t + 11/7) + 42/5 * sin(9 * t + 11/7) + 3273/5) * theta(47 * pi - t) * theta(t - 43 * pi) + (-32/5 * sin(11/7 - 27 * t) - 29/6 * sin(11/7 - 25 * t) - 46/7 * sin(11/7 - 23 * t) - 70/23 * sin(11/7 - 20 * t) - 43/5 * sin(11/7 - 15 * t) - 53/4 * sin(11/7 - 14 * t) - 127/16 * sin(11/7 - 13 * t) - 10/3 * sin(11/7 - 8 * t) - 12/5 * sin(11/7 - 7 * t) - 42/5 * sin(8/5 - 6 * t) - 29/4 * sin(8/5 - 5 * t) - 35/4 * sin(8/5 - 4 * t) - 64/13 * sin(8/5 - 3 * t) - 40/3 * sin(8/5 - 2 * t) - 250/7 * sin(8/5 - t) + 1/4 * sin(9 * t + 9/2) + 45/22 * sin(10 * t + 14/3) + 22/5 * sin(11 * t + 8/5) + 27/4 * sin(12 * t + 8/5) + 41/5 * sin(16 * t + 8/5) + 1/4 * sin(17 * t + 9/2) + 12/5 * sin(18 * t + 14/3) + 28/3 * sin(19 * t + 8/5) + 3/4 * sin(21 * t + 5/3) + 31/5 * sin(22 * t + 8/5) + 4 * sin(24 * t + 8/5) + 11/5 * sin(26 * t + 8/5) + 4/5 * sin(28 * t + 3/2) + 493) * theta(43 * pi - t) * theta(t - 39 * pi) + (-9/5 * sin(11/7 - 24 * t) - 9/5 * sin(3/2 - 20 * t) - 2/3 * sin(5/4 - 18 * t) - 31/4 * sin(8/5 - 15 * t) + 259/3 * sin(t + 33/7) + 88/5 * sin(2 * t + 14/3) + 83/4 * sin(3 * t + 8/5) + 209/6 * sin(4 * t + 8/5) + 149/4 * sin(5 * t + 8/5) + 271/8 * sin(6 * t + 8/5) + 64/3 * sin(7 * t + 8/5) + 29/4 * sin(8 * t + 8/5) + 55/7 * sin(9 * t + 8/5) + 16/7 * sin(10 * t + 8/5) + 13/7 * sin(11 * t + 8/5) + 13/5 * sin(12 * t + 14/3) + 24/5 * sin(13 * t + 14/3) + 6 * sin(14 * t + 8/5) + 23/6 * sin(16 * t + 8/5) + 32/5 * sin(17 * t + 11/7) + 39/4 * sin(19 * t + 8/5) + 3 * sin(21 * t + 8/5) + 7 * sin(22 * t + 14/3) + 1/5 * sin(23 * t + 26/9) + 25/8 * sin(25 * t + 11/7) + 3/2 * sin(26 * t + 3/2) + 22/7 * sin(27 * t + 8/5) + 3186/7) * theta(39 * pi - t) * theta(t - 35 * pi) + (-23/8 * sin(3/2 - 14 * t) - 11/3 * sin(3/2 - 12 * t) - 5/4 * sin(4/3 - 10 * t) - 79/3 * sin(11/7 - 9 * t) - 2/3 * sin(4/3 - 6 * t) - 392/3 * sin(11/7 - 5 * t) - 87/4 * sin(11/7 - 4 * t) - 731/5 * sin(8/5 - 2 * t) + 619/5 * sin(t + 8/5) + 73/5 * sin(3 * t + 14/3) + 23/5 * sin(7 * t + 5/3) + 168/5 * sin(8 * t + 8/5) + 23/6 * sin(11 * t + 14/3) + 1/7 * sin(13 * t + 13/3) - 455/2) * theta(35 * pi - t) * theta(t - 31 * pi) + (-27/13 * sin(11/12 - 9 * t) - 23/5 * sin(11/7 - 5 * t) - 5853/22 * sin(3/4 - t) + 173/6 * sin(2 * t + 1/20) + 23/4 * sin(3 * t + 8/3) + 78/5 * sin(4 * t + 3/2) + 40/13 * sin(6 * t + 20/7) + 5/2 * sin(7 * t + 17/4) + 9/5 * sin(8 * t + 7/5) + 2/5 * sin(10 * t + 21/11) - 2558/3) * theta(31 * pi - t) * theta(t - 27 * pi) + (-17/8 * sin(3/4 - 10 * t) - 7/4 * sin(7/6 - 7 * t) + 21/11 * sin(t + 17/6) + 11/7 * sin(2 * t + 2/5) + 7/4 * sin(3 * t + 1/4) + 8/5 * sin(4 * t + 14/5) + 19/3 * sin(5 * t + 29/7) + 69/5 * sin(6 * t + 10/3) + 11/5 * sin(8 * t + 1/4) + 34/11 * sin(9 * t + 23/8) + 877/5) * theta(27 * pi - t) * theta(t - 23 * pi) + (-93/23 * sin(5/4 - 5 * t) + 19/6 * sin(t + 3/5) + 1/10 * sin(2 * t + 1/4) + 14/5 * sin(3 * t + 7/5) + 13/5 * sin(4 * t + 4/5) + 25/3 * sin(6 * t + 2/5) + 79/8 * sin(7 * t + 1/6) + 2 * sin(8 * t + 14/5) + 25/8 * sin(9 * t + 4) + 5/3 * sin(10 * t + 9/8) + 847/5) * theta(23 * pi - t) * theta(t - 19 * pi) + (-4 * sin(1/4 - 2 * t) - 154/3 * sin(1/3 - t) + 699/4) * theta(19 * pi - t) * theta(t - 15 * pi) + (-2/5 * sin(1 - 4 * t) - 14/3 * sin(5/4 - 3 * t) - 91/2 * sin(1/2 - t) + 13/5 * sin(2 * t + 8/3) + 170) * theta(15 * pi - t) * theta(t - 11 * pi) + (-12/5 * sin(7/5 - 9 * t) - 24/5 * sin(2/5 - 3 * t) - 249/4 * sin(1/5 - t) + 63/4 * sin(2 * t + 17/5) + 19/5 * sin(4 * t + 10/3) + 2 * sin(5 * t + 22/5) + 51/13 * sin(6 * t + 18/5) + 5/2 * sin(7 * t + 17/4) + 13/5 * sin(8 * t + 19/5) + 14/13 * sin(10 * t + 21/5) + 917/5) * theta(11 * pi - t) * theta(t - 7 * pi) + (-7/5 * sin(1/2 - 10 * t) - sin(5/6 - 9 * t) - 13/7 * sin(7/5 - 8 * t) - 7/4 * sin(6/5 - 7 * t) - 11/6 * sin(1 - 3 * t) + 277/5 * sin(t + 1/10) + 128/7 * sin(2 * t + 33/8) + 19/4 * sin(4 * t + 17/4) + 3/2 * sin(5 * t + 19/5) + 13/4 * sin(6 * t + 22/5) + 539/3) * theta(7 * pi - t) * theta(t - 3 * pi) + (-19/4 * sin(1 - 10 * t) + 8238/7 * sin(t + 26/7) + 136/5 * sin(2 * t + 7/4) + 306/7 * sin(3 * t + 5/3) + 75/4 * sin(4 * t + 2/3) + 68/5 * sin(5 * t + 13/4) + 23/3 * sin(6 * t + 32/7) + 17/4 * sin(7 * t + 9/4) + 4 * sin(8 * t + 3/5) + 2/3 * sin(9 * t + 1/3) - 163/2) * theta(3 * pi - t) * theta(t + pi)) * theta(sqrt(sgn(sin(t/2))))

# %%
t_values = np.linspace(0, 152 * pi, 2500000)

# Calculate x and y using the functions
x_values = []
y_values = []
for t in t_values:
    try:
        x_compute = xt(t)
    except ValueError:
        continue
    try:
        y_compute = yt(t)
    except ValueError:
        continue
    x_values.append(x_compute)
    y_values.append(y_compute)

# %%
plt.figure(figsize=(10, 10))
plt.scatter(x_values, y_values, c = "gray", s = 0.1, alpha = 0.5)

plt.title('Einstein')

plt.axis("off")

plt.show()

# %% [markdown]
# # Footnotes
# Referenced [Plotting (Need)](https://sps.nus.edu.sg/sp2273/docs/python_basics/07_plotting/1_plotting_need.html)
