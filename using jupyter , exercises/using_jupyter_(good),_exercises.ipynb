# %%
from IPython.core.display import HTML

HTML("""
    <link rel="stylesheet" href="../fonts/cmun-bright.css">
    <style type='text/css'>
        * {
            font-family: Computer Modern Bright !important;
        }
    </style>
""")
# Out:
#     <link rel="stylesheet" href="../fonts/cmun-bright.css">
#     <style type='text/css'>
#         * {
#             font-family: Computer Modern Bright !important;
#         }
#     </style>

# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">1 Using Jupyter (Good), Exercises</span></div>

# %% [markdown]
# # Exercise 1 (Learning to interrupt)

# %%
# while True:
#     print('*', end="")

while True:
    print("*", end="")
    break
# Out:
# *

# %% [markdown]
# # Exercise 2 (Resetting & Restarting the Kernal)

# %%
# print = "PRINT"
# get_ipython().kernel.do_shutdown("immediate")

print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # Footnotes
# Referenced [Using Jupyter (Good), Exercises](https://sps.nus.edu.sg/sp2273/docs/python_basics/01_using_jupyter/2_using-jupyter_good_exercises.html)
